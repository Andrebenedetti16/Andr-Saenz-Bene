# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Análise de Dados: Controle de Versão II
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Adicionar e salvar;</li>
#   <li>Visualizar e reverter;</li>
#   <li>Persistir e atualizar.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. Setup

# %% [markdown]
# Para realizar os exercicios vamos configurar o `git` e trazer o projeto do GitHub para a a máquina virtual do Google Colab (ou na sua máquina local, as instruções são as mesmas). Para tanto, replique as atividades expostas na aula 1 deste módulo.

# %% [markdown]
# ### **1.1. Autenticação**

# %% [markdown]
# Nesta etapa, vamos configura o `git` com suas credenciais.

# %%
import os

username = "Andrebenedetti16" # insira o seu nome de usuário do git
os.environ["GITHUB_USER"] = username

# !git config --global user.name "${GITHUB_USER}"

# %%
import os
from getpass import getpass

usermail = getpass()
os.environ["GITHUB_MAIL"] = usermail

# !git config --global user.email "${GITHUB_MAIL}"
# Out:
# ··········

# %%
import os
from getpass import getpass

usertoken = getpass()
os.environ["GITHUB_TOKEN"] = usertoken
# Out:
# ··········

# %% [markdown]
# ### **1.2. Projeto**

# %% [markdown]
# Nesta etapa, vamos trazer o projeto do GitHub para máquina local.

# %%
# !git clone https://github.com/${GITHUB_USER}/Andr-Saenz-Bene.git
# Out:
# Cloning into 'Andr-Saenz-Bene'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# !ls /content
# Out:
# sample_data

# %%
# %cd /content/Andr-Saenz-Bene/
# Out:
# /content/Andr-Saenz-Bene

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ---

# %% [markdown]
# ## 2\. Preço da gasolina

# %% [markdown]
# O código abaixo gera um arquivo com o preço médio de venda da gasolina na cidade de São Paulo nos 10 primeiros dias de Julho de 2021.

# %%
# %%writefile gasolina.csv
# dia,venda
# 1,5.11
# 2,4.99
# 3,5.02
# 4,5.21
# 5,5.07
# 6,5.09
# 7,5.13
# 8,5.12
# 9,4.94
# 10,5.03
# Out:
# Writing gasolina.csv

# %% [markdown]
# ### **2.1. Desenvolvimento**

# %% [markdown]
# Gere uma gráfico de linha utilizando os dados do arquivo `gasolina.csv` com o dia no eixo `x`
#  e o seu preço no eixo `y` utilizando os pacotes Python de sua preferência, como o Pandas e o Seaborn. Salve o gráfico no arquivo `gasolina.png` e o seu código Python de geração no arquivo `gasolina.py`.

# %%
# código de geração do gráfico

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df_gasolina = pd.read_csv('gasolina.csv')

plt.figure(figsize=(10, 6))
sns.lineplot(data=df_gasolina, x='dia', y='venda')
plt.title('Preço da Gasolina em São Paulo (Julho de 2021)')
plt.xlabel('Dia de Julho de 2021')
plt.ylabel('Preço Médio (R$)')
plt.grid(True)
plt.savefig('gasolina.png')

# %% [markdown]
# Criar um Arquivo e salvar as alterações em um repositório local

# %%
# !touch gasolina.py

# %% [markdown]
# ### **2.2. Git**

# %% [markdown]
# Utilizando os comandos do `git`, adicione e "commite" os arquivos gerados (base, código Python e gráfico).

# %%
# comandos git para adicionar e commitar os arquivos
import os
import shutil

# Mover os arquivos para o diretório do repositório
shutil.move('/content/gasolina.csv', '/content/Andr-Saenz-Bene/gasolina.csv')
shutil.move('/content/gasolina.py', '/content/Andr-Saenz-Bene/gasolina.py')
shutil.move('/content/gasolina.png', '/content/Andr-Saenz-Bene/gasolina.png')

# Mudar para o diretório do repositório
os.chdir('/content/Andr-Saenz-Bene')

# Comandos git para adicionar e commitar os arquivos
# !git add gasolina.csv gasolina.py gasolina.png
# !git commit -m "Add gasolina data, code and plot"
# Out:
# [novo_projeto 71ffd69] Add gasolina data, code and plot
#  3 files changed, 24 insertions(+)
#  create mode 100644 gasolina.csv
#  create mode 100644 gasolina.png
#  create mode 100644 gasolina.py

# %% [markdown]
# ### **2.3. Github**

# %% [markdown]
# Utilizando os comandos do `git`, envie o seu commit para o GitHub.

# %%
# comandos git para enviar o commit para o GitHub
# !git status
# Out:
# On branch novo_projeto
# Your branch is ahead of 'origin/novo_projeto' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %% [markdown]
# ---

# %% [markdown]
# ## 3\. Arquivo README.md

# %% [markdown]
# O arquivo README.md é a porta de entrada do seu projeto, é ele que será renderizado quando o seu projeto for acessado, portanto, é importante que ele esteja bem escrito. Alguns exemplos:

# %% [markdown]
#  - [Pandas](https://github.com/pandas-dev/pandas);
#  - [Seaborn](https://github.com/mwaskom/seaborn);
#  - [Spark Cluster on Docker](https://github.com/cluster-apps-on-docker/spark-standalone-cluster-on-docker), esse projeto é meu! :)

# %% [markdown]
# ### **3.1. Desenvolvimento**

# %% [markdown]
# Altere o arquivo README.md com informações sobre seu repositório, inclua um título e uma breve descrição do repositório (no mínimo).

# %% [markdown]
# > **Dica**: o README.md pode ser configurado utilizando o padrão **markdown**, o mesmo que utilizamos nas células de texto aqui no Google Colab.

# %%
# %%writefile README.md
# # Meu Repositório de Exercícios
#
# Este repositório contém os exercícios do módulo de Análise de Dados: Controle de Versão II da EBAC.
# Out:
# Overwriting README.md

# %% [markdown]
# ### **3.2. Git**

# %% [markdown]
# Utilizando os comandos do `git`, adicione e "commite" as alterações no arquivo `README.md`.

# %%
# comandos git para adicionar e commitar os arquivos
# !git add README.md
# !git commit -m "Update README.md with title and description"
# Out:
# [novo_projeto 43643da] Update README.md with title and description
#  1 file changed, 3 insertions(+), 2 deletions(-)

# %% [markdown]
# ### **3.3. Github**

# %% [markdown]
# Utilizando os comandos do `git`, envie o seu commit para o GitHub.

# %%
# comandos git para enviar o commit para o GitHub
# !git push https://${GITHUB_USER}:${GITHUB_TOKEN}@github.com/${GITHUB_USER}/Andr-Saenz-Bene.git
# Out:
# fatal: unable to access 'https://github.com:Andrebenedetti16/Andr-Saenz-Bene.git@github.com/Andrebenedetti16/Andr-Saenz-Bene.git/': URL using bad/illegal format or missing URL

# %%
# Executar novamente o comando de clonagem
# !git clone https://github.com/${GITHUB_USER}/Andr-Saenz-Bene.git
# Out:
# fatal: destination path 'Andr-Saenz-Bene' already exists and is not an empty directory.

# %%
# Verificar o conteúdo do diretório /content
# !ls /content
# Out:
# Andr-Saenz-Bene  gasolina.csv  gasolina.png  gasolina.py  sample_data

# %%
# Configurar a URL remota do repositório com o token
import os

# Mudar para o diretório do repositório para garantir que o comando git remote funcione
os.chdir('/content/Andr-Saenz-Bene')

# Configurar a URL remota 'origin' com o token de acesso
# !git remote set-url origin https://${GITHUB_USER}:${GITHUB_TOKEN}@github.com/${GITHUB_USER}/Andr-Saenz-Bene.git
